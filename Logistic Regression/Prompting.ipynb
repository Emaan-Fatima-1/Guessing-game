# %% [markdown]
# <a href="https://colab.research.google.com/github/Emaan-Fatima-1/Guessing-game/blob/main/Logistic%20Regression/Prompting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
